# %% [markdown]
# # Семинар №11 - Вопросно-ответная система

# %% [markdown]
# Сделаем поисковую систему на основе BM25 и BERT, чтобы отфильтровать научные работы по запросу.

# %% [markdown]
# ## Bert for QA
# ![bert.png](./imgs/bert.png)
#
# BERT (Bidirectional Encoder Representations from Transformers) - недавняя статья, опубликованная исследователями Google AI Language. Она вызвала ажиотаж в сообществе машинного обучения, представив самые современные результаты в широком спектре задач NLP, включая ответы на вопросы (SQuAD v1.1), вывод на естественном языке (MNLI) и другие.
#
# Ключевым техническим новшеством БЕРТА является применение двунаправленного обучения Transformer, популярной модели внимания, к языковому моделированию. Это контрастирует с предыдущими попытками, в которых рассматривалась последовательность текста либо слева направо, либо комбинированное обучение слева направо и справа налево. Результаты работы показывают, что языковая модель, которая обучается в двух направлениях, может иметь более глубокое представление о языковом контексте и потоке, чем однонаправленные языковые модели. В статье исследователи подробно описывают новую технику под названием Masked LM (MLM), которая позволяет проводить двунаправленное обучение в моделях, в которых ранее это было невозможно.
#
# Question answering (QA) - дисциплина компьютерных наук в области поиска информации и обработки естественного языка (NLP), которая занимается созданием систем, автоматически отвечающих на вопросы, задаваемые людьми на естественном языке.
#
# ## BM25
# ![image.png](./imgs/bm25_formula.jpg)
#
# Здесь:
# - D - документ.
# - Q - запрос.
# - f(q_i, D) - число вхождений слова q_i в документ.
# - |D| - длина документа.
# - avgdl - средняя длина документов в коллекции.
# - N - число документов в коллекции.
# - n(q_i) - число документов, содержащих слово q_i.
# - k_1 - параметр в диапазоне [1.2, 2.0].
# - b - параметр, обычно 0.75.
# - $\delta$ - параметр, обычно 1.
#
# В области поиска информации Okapi BM25 (BM - сокращение от best matching) - это функция ранжирования, используемая поисковыми системами для оценки релевантности документов заданному поисковому запросу. Он основан на системе вероятностного поиска, разработанной в 1970-х и 1980-х годах Стивеном Э. Робертсоном, Карен Сперк Джонс и другими.
#
# Название фактической функции ранжирования - BM25. Более полное название, Okapi BM25, включает название первой системы, которая его использовала, - информационно-поисковой системы Okapi, внедренной в Лондонском городском университете в 1980-х и 1990-х годах. BM25 и его более новые варианты, например BM25F (версия BM25, которая может учитывать структуру документа и текст привязки), представляют собой современные функции поиска, подобные TF-IDF, используемые при поиске документов.
#
# Почитать про BM25: https://habr.com/ru/articles/823568/

# %% [markdown]
# ## Install and import packages

# %%
# !pip install rank_bm25 nltk transformers
# !pip install ipywidgets
# Out:
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rank_bm25) (1.26.4)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (7.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.17.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.23.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.9 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.2

# %%
import re
import os
import json
from pathlib import Path, PurePath

import requests
from requests.exceptions import HTTPError, ConnectionError

import numpy as np
import pandas as pd
from tqdm import tqdm
from rank_bm25 import BM25Okapi

import nltk
from nltk.corpus import stopwords
nltk.download("punkt")
nltk.download('stopwords')
nltk.download('punkt_tab')

import torch
from transformers import BertTokenizer, BertForQuestionAnswering

import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# # Предварительная обработка данных
#
# [Загрузите](https://disk.yandex.ru/d/Z3MfKtbtCwdZkw) полнотекстовые публикации и очистите их.

# %%
merged = pd.read_csv(r'processed_data_v8_2 2.csv', sep=';')

# %%
merged.head()
# Out:
#    paper_id                                            authors  \
# 0  sl79r65r  Zhang, Zhonghua; Jiang, Shan; Liu, Yun; Sun, Y...
# 1  wvx6q999                                                NaN
# 2  z9jnljrt  Cao, Yurou; Gao, Lulu; Zhang, Li; Zhou, Lixian...
# 3  dqpujzo8  Li, Hong-Ying; Zhu, Guang-Jian; Zhang, Yun-Zhi...
# 4  q6mhqcho  Zhou, Zhen; Zhang, Pan; Cui, Yuxia; Zhang, Yon...
#
#                                                title  \
# 0  Identification of ireA, 0007, 0008, and 2235 a...
# 1  Note from the editors: novel coronavirus (2019...
# 2  Genome-wide screening of lipoproteins in Actin...
# 3  A qualitative study of zoonotic risk factors a...
# 4  Experiments Investigating the Competitive Grow...
#
#                                             abstract  \
# 0  Avian pathogenic Escherichia coli (APEC), a pa...
# 1                                                NaN
# 2  Actinobacillus pleuropneumoniae is an importan...
# 3  BACKGROUND: Strategies are urgently needed to ...
# 4  Human metapneumovirus (hMPV) is an important p...
#
#                                                 text        date  \
# 0  Avian pathogenic Escherichia coli (APEC), a pa...  2020-01-23
# 1  At the end of 2019, on 31 December, the World ...  2020-01-23
# 2  Actinobacillus pleuropneumoniae is a Gram-nega...  2020-02-11
# 3  Emerging and re-emerging zoonotic diseases are...  2020-02-10
# 4  Human metapneumovirus (hMPV), which was first ...  2020-02-18
#
#                                                  url  risk_factor_age  \
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...            False
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...            False
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...            False
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...             True
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...             True
#
#    risk_factor_sex  risk_factor_overweight  ...  \
# 0            False                   False  ...
# 1            False                   False  ...
# 2            False                   False  ...
# 3             True                   False  ...
# 4            False                   False  ...
#
#    tag_design_retrospective_cohort  tag_design_cross_sectional_case_control  \
# 0                            False                                    False
# 1                            False                                    False
# 2                            False                                    False
# 3                            False                                    False
# 4                            False                                    False
#
#    tag_design_matched_case_control  tag_design_prevalence_survey  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
# 3                            False                         False
# 4                            False                         False
#
#    tag_design_time_series_analysis  tag_design_systematic_review  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
# 3                            False                         False
# 4                            False                         False
#
#    tag_design_randomized_control  tag_design_pseudo_randomized_control  \
# 0                          False                                 False
# 1                          False                                 False
# 2                          False                                 False
# 3                          False                                 False
# 4                          False                                 False
#
#    tag_design_case_study  tag_design_simulation
# 0                  False                  False
# 1                  False                  False
# 2                  False                  False
# 3                  False                  False
# 4                   True                  False
#
# [5 rows x 36 columns]

# %%
f = merged.loc[0].to_frame().fillna('')
f.columns = ['Value']
f.iloc[:10]
# Out:
#                                                                     Value
# paper_id                                                         sl79r65r
# authors                 Zhang, Zhonghua; Jiang, Shan; Liu, Yun; Sun, Y...
# title                   Identification of ireA, 0007, 0008, and 2235 a...
# abstract                Avian pathogenic Escherichia coli (APEC), a pa...
# text                    Avian pathogenic Escherichia coli (APEC), a pa...
# date                                                           2020-01-23
# url                     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# risk_factor_age                                                     False
# risk_factor_sex                                                     False
# risk_factor_overweight                                              False

# %% [markdown]
# ## Задача №1
#
# Создайте классную работу, чтобы упростить получение какого-либо поля, такого как аннотация, полный текст, doi и так далее.

# %%
class Paper:
    def __init__(self, item):
        self.paper = item.to_frame().fillna('')
        # self.paper.columns = ['Value']
    def url(self):
        return self._get_field('url')
    def text(self):
        return self._get_field('text')
    def abstract(self):
        return self._get_field('abstract')
    def title(self):
        return self._get_field('title')
    def authors(self, split=False):
        return self._get_field('authors')
    def _get_field(self, field_name):
        return self.paper.get(field_name, '')

# %% [markdown]
# ## Задача №2
#
# Некоторые функции предварительной обработки для очистки исходных данных. Мы обозначаем текст, удаляем знаки препинания и некоторые специальные символы.

# %%
english_stopwords = list(set(stopwords.words('english')))
SEARCH_DISPLAY_COLUMNS = ['title', 'abstract', 'url', 'authors', 'text']

# %%
def strip_characters(text):
    return re.sub(r'[\(\)\[\]\{\}:;,\\.!?\'\"-]', '', text)

def clean(text):
    text = text.lower()
    text = strip_characters(text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def tokenize(text):
    words = nltk.word_tokenize(text)
    return list(
        set([word for word in words
             if len(word) > 1
             and not word in english_stopwords
             and not (word.isnumeric() and len(word) is not 4)
             and (not word.isnumeric() or word.isalpha())])
    )

def preprocess(text):
    t = clean(text)
    tokens = tokenize(t)
    return tokens

# %% [markdown]
# # Поисковая система BM25
# Определите класс для построения индекса и поиска по строкам.

# %%
class SearchResults:
    def __init__(self,
                 data: pd.DataFrame,
                 columns = None):
        self.results = data
        if columns:
            self.results = self.results[columns]

    def __getitem__(self, item):
        return Paper(self.results.loc[item])

    def __len__(self):
        return len(self.results)

    def set_ans(self, ans):
        col_name = self.results.columns.tolist()
        col_name.insert(2, 'Answer')
        self.results = self.results.reindex(columns=col_name)
        self.results['Answer'] = ans

# %%
class WordTokenIndex:
    def __init__(self,
                 corpus: pd.DataFrame,
                 columns=SEARCH_DISPLAY_COLUMNS):
        self.corpus = corpus

        raw_search_str = self.corpus.abstract.fillna('') + ' ' + self.corpus.title.fillna('')
        self.index = raw_search_str.apply(preprocess).to_frame()
        self.index.columns = ['terms']
        self.index.index = self.corpus.index
        self.columns = columns

    def search(self, search_string):
        search_terms = preprocess(search_string)
        # получить индексы, включающие строку search_string
        result_index = self.index.terms.apply(lambda terms: any(i in terms for i in search_terms))
        # получить найденные papers
        results = self.corpus[result_index].copy().reset_index().rename(columns={'index':'paper'})

        return SearchResults(results, self.columns + ['paper'])

# %%
class RankBM25Index(WordTokenIndex):
    def __init__(self, corpus: pd.DataFrame, columns=SEARCH_DISPLAY_COLUMNS):
        super().__init__(corpus, columns)
        self.bm25 = BM25Okapi(self.index.terms.tolist())

    def search(self, search_string, n=4):
        search_terms = preprocess(search_string)
        doc_scores = self.bm25.get_scores(search_terms)

        ind = np.argsort(doc_scores)[::-1][:n]
        results = self.corpus.iloc[ind][self.columns]
        results['Score'] = doc_scores[ind]
        results = results[results.Score > 0]

        return SearchResults(results.reset_index(), self.columns + ['Score'])

# %% [markdown]
# # Bert furtuer pre-train and fine
# Используйте реализацию transformers bert и загрузите предварительно обученную модель "bert-base-uncased". Мы используем все статьи в качестве корпуса для дальнейшего предварительного обучения bert задаче языковой модели. После дальнейшей предварительной подготовки мы используем набор данных SQuAD-2.0 для точной настройки модели bert. Наконец, мы сохраняем обученную модель, которая называется "output_squad".

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForQuestionAnswering.from_pretrained('bert-base-uncased')
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # QA function
# Создайте функцию контроля качества, которая получает вопрос и фрагмент текста, передает их в модель bert и выводит возможный ответ в тексте. Если модель выдает неверный ответ, функция выдаст "Нет ответа".

# %% [markdown]
# ## Постройте пайплайн поиска и покажите результаты
#
# ### Задача №3
# Мы показываем выходные данные модели в таблицах и заключаем их в "【】", чтобы представить ответ в статье.

# %%
max_question_len = 100

def getAnswer(question, text):
    input_ids = tokenizer.encode(question, text, max_length=512, truncation=True)
    # mask text sequence  # 102 - SEP между question и text
    token_type_ids = [0 if i <= input_ids.index(102) else 1 for i in range(len(input_ids))]

    model_out = model(torch.tensor([input_ids]), token_type_ids=torch.tensor([token_type_ids]))
    start_scores, end_scores = model_out['start_logits'], model_out['end_logits']

    all_tokens = tokenizer.convert_ids_to_tokens(input_ids)

    # выделить  часть за начало ответа и его конец
    start_scores = start_scores[0, input_ids.index(102):]  # bs = 1
    end_scores = end_scores[0, input_ids.index(102):]  # bs = 1

    if torch.argmax(start_scores).item() >= torch.argmax(end_scores).item():
        return "No Answer"

    # выделить токены до ответа + [ начало контекста ответа
    all_tokens = all_tokens[: input_ids.index(102) + torch.argmax(start_scores)] + ["【"] + all_tokens[input_ids.index(102) + torch.argmax(start_scores):]
    # выделить токены конца ответа контекста ] + токены после ответа
    all_tokens = all_tokens[: input_ids.index(102) + torch.argmax(end_scores) + 1] + ["】"] + all_tokens[input_ids.index(102) + torch.argmax(end_scores) + 1:]

    # найти начало и конец ответа
    start_span = max(input_ids.index(102) + torch.argmax(start_scores) - 5, input_ids.index(102))
    end_span = min(input_ids.index(102) + torch.argmax(end_scores) + 6, len(all_tokens) + 1)

    answer = tokenizer.convert_tokens_to_string(all_tokens[start_span:end_span])
    answer = answer.replace("[SEP]", "")
    return answer

# %%
text = merged.iloc[0].text
text
# Out:
# 'Avian pathogenic Escherichia coli (APEC), a pathotype of extraintestinal pathogenic E. coli (ExPEC), causes serious infectious diseases in poultry [1, 2]. Different serotypes of APEC cause local or systemic infectious diseases in poultry, including respiratory infections, sepsis, polyserositis, coligranuloma, cellulitis, yolk sac infection, omphalitis, and swollen head syndrome, resulting in significant economic losses to the poultry industry [3]. Strains of APEC and neonatal meningitis-associated E. coli (NMEC, a subpathotype of ExPEC), the latter of which causes infections in humans, reportedly share some common virulence genes [4–6]. It is thus particularly important to study the genes encoding virulence factors in APEC strains. These strains contain several virulence-associated genes that encode various virulence factors, including adhesins (fimC, ompA, papC), invasins (ibeA), avian haemolysins (hlyF), serum survival proteins (iss, ompT), and siderophores (iutA, fyuA, iroN); moreover, they show the presence of a pathogenicity island [7–9].\nIron is a vital micronutrient that regulates enzyme activity and metabolism. This element plays a key role in basic cellular processes, such as cellular respiration, DNA replication, and electron transport and is accordingly essential for bacterial survival in host tissues [10–12]. Furthermore, iron is a necessary growth factor for bacteria and is reportedly involved in the expression of bacterial virulence factors [13]. Iron uptake factors evidently play a pivotal role in E. coli growth and pathogenesis. Bacteria employ different strategies to absorb iron from their environment, including siderophore-mediated iron uptake, which occurs on the cell surface [14]. In addition, bacteria either excessively reduce the external pH or dissolve iron oxide to meet their iron requirements by reducing ferric iron to a relatively soluble ferrous form. Another common strategy is to synthesize and secrete iron chelators, such as siderophores, as intracellular iron (Fe2+) is rarely found in natural conditions, and Fe2+ can be readily oxidized to Fe3+ in the presence of oxygen and water [15]. Siderophores then combine with the available iron (Fe3+) to form an iron–siderophore complex, which binds to specific receptor proteins on the bacterial cell surface, consequently entering cells via the TonB-dependent transport system, followed by iron release. Siderophore-mediated ferric uptake requires specific outer membrane (OM) receptors, such as FhuA, FecA, and FepA, which reportedly exist in E. coli [16]. These OM receptors share the same structural properties and acquire energy by coupling with TonB proteins located in the inner membrane, and they are referred to as TonB-dependent receptors (TBDRs) [17].\nTBDRs are known to actively transport ferric–siderophore complexes in Gram-negative bacteria, and they also transport diverse antibiotics, vitamins, nickel complexes, and carbohydrates [18–20]. Transporters involved in iron uptake have very strict siderophore selectivity. A strong correlation exists between the amount of iron and siderophores that bacteria can use and the number of genes encoding iron-regulated TBDRs [19]. In simple terms, iron depletion triggers the upregulation of genes encoding TBDRs.\nIn this study, upon analysing the whole genome of the APEC strain DE205B, we identified six putative TBDRs; however, the construction of two mutants failed. Thus, we eventually investigated the roles of four putative TBDRs—ireA, 0007, 0008, and 2235—in iron uptake.\nThe bacterial strains and plasmids used in this study are listed in Table 1. The APEC strain DE205B (O2:K1), which was isolated from a duck with neurological symptoms, was previously determined to have no antibiotic (ampicillin, kanamycin, and chloramphenicol) resistance [21–25]. All the APEC strains used in this study were cultured in Luria–Bertani (LB, Oxoid, Thermo-Fisher, USA) or solid LB medium supplemented with 2% agar, followed by incu ...

# %%
query = 'What is it omphalitis'
text = merged.iloc[0].text
getAnswer(query, text)
# Out:
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# 'to the poultry industry [ 【 3 ] . strains of apec and neonatal meningitis - associated e . coli ( nmec , a subpathotype of expec ) , the latter of which causes infections in humans , reportedly share some common virulence genes [ 4 – 6 ] . it is thus particularly important to study the genes encoding virulence factors in apec strains . these strains contain several virulence - associated genes that encode various virulence factors , including adhesins ( fimc , ompa , papc ) , invasins ( ibea ) , avian haemolysins ( hlyf ) , serum survival proteins ( iss , ompt ) , and siderophores ( iuta , fyua , iron ) ; moreover , they show the presence of a pathogenicity island [ 7 – 9 ] . iron is a vital micronutrient that regulates enzyme activity and metabolism . this element plays a key 】 role in basic cellular'

# %% [markdown]
# ### Задача №4
# Соберем весь процесс поиска в одной функции.

# %%
bm25_index = RankBM25Index(merged)

# %%
def searchAndGetAnswer(question, top_bm=50, top_k=10):
    assert top_bm > top_k and top_bm > 1 and top_k > 1, 'set top_bm > top_k > 1'
    results = bm25_index.search(question, top_bm)
    ans_list = []
    ans_index = []
    for i in range(len(results)):
        text = results[i].text()
        ans = getAnswer(question, text)
        if ans != "No Answer":
            ans_list.append(ans)
            ans_index.append(i)
            print(f"{len(ans_index)}/{top_k}")
            if len(ans_index) >= top_k:
                break
    if not ans_index:
        print("No valid answers found.")
        return results.results
    final_results = results.results.iloc[ans_index].reset_index(drop=True)
    final_results = final_results.copy()
    final_results['Answer'] = ans_list
    cols = ['title', 'abstract', 'Answer', 'Score', 'url', 'authors']
    res = final_results.loc[:, cols]
    return res

# %% [markdown]
# ### Q1: *Real-time tracking of whole genomes and a mechanism for coordinating the rapid dissemination of that information to inform the development of diagnostics and therapeutics and to track variations of the virus over time.*

# %%
p = "Real-time tracking of whole genomes and a mechanism for coordinating the rapid dissemination of that information to inform the development of diagnostics and therapeutics and to track variations of the virus over time."
res = searchAndGetAnswer(p)
res
# Out:
# No valid answers found.
#                                                 title  \
# 0   Genome Detective Coronavirus Typing Tool for r...
# 1   Genome Detective Coronavirus Typing Tool for r...
# 2   Genotyping coronavirus SARS-CoV-2: methods and...
# 3   Genotyping coronavirus SARS-CoV-2: Methods and...
# 4   BioLaboro: A bioinformatics system for detecti...
# 5   MINERVA: A facile strategy for SARS-CoV-2 whol...
# 6   The ongoing COVID-19 epidemic in Minas Gerais,...
# 7   Differences in power-law growth over time and ...
# 8   Infection and Rapid Transmission of SARS-CoV-2...
# 9   Tracking COVID-19 in Europe: Infodemiology App...
# 10  Epidemiological data from the COVID-19 outbrea...
# 11  Current development of COVID-19 diagnostics, v...
# 12        Short-Term Covid-19 Forecast for Latecomers
# 13  Research on the Influence of Information Diffu...
# 14  An Interactive Online Dashboard for Tracking C...
# 15  A doubt of multiple introduction of SARS‐CoV‐2...
# 16  Internet Search Patterns Reveal Clinical Cours...
# 17  Dynamics of transmissible gastroenteritis viru...
# 18  Building an International Consortium for Track...
# 19  Artificial Intelligence (AI) applications for ...
# 20  People Behavior Changes in China during COVID-...
# 21  Artificial Intelligence (AI) applications for ...
# 22  Development and Evaluation of A CRISPR-based D...
# 23  The genomic variation landscape of globally-ci...
# 24  Diagnosing COVID-19: The Disease and Tools for...
# 25  Shared Antigen-specific CD8+ T cell Responses ...
# 26  Spike mutation pipeline reveals the emergence ...
# 27  Rapid, sensitive, full genome sequencing of Se...
# 28  Potential Rapid Diagnostics, Vaccine and Thera...
# 29  COVID-19 pandemic: an overview of epidemiology...
# 30  Structural and Functional Implications of Non-...
# 31  Rapid implementation of real-time SARS-CoV-2 s...
# 32  Testing on the Move South Korea’s rapid respon...
# 33  Rapid establishment of laboratory diagnostics ...
# 34  The Viral Infection and Respiratory Illness Un...
# 35  Failure of the cobas(R) SARS-CoV-2 (Roche) E-g...
# 36  Characterizing geographical and temporal dynam...
# 37  Where to buy face masks? Survey of application...
# 38  Machine learning using intrinsic genomic signa...
# 39  Racing Towards the Development of Diagnostics ...
# 40  Evolution and variation of 2019-novel coronavirus
# 41  Large scale genomic analysis of 3067 SARS-CoV-...
# 42  Intelligent classification of platelet aggrega...
# 43  Postintubation Dysphagia During COVID-19 Outbr...
# 44  Development of a Novel, Genome Subtraction-Der...
# 45  2019 novel coronavirus is undergoing active re...
# 46    COVID-19: A promising cure for the global panic
# 47  Estimation of COVID-19 spread curves integrati...
# 48  Maximum entropy method for estimating the repr...
# 49  COVID-19 for the Cardiologist: A Current Revie...
#
#                                              abstract  \
# 0   SUMMARY: Genome Detective is a web-based, user...
# 1   Genome Detective is a web-based, user-friendly...
# 2   The emerging global infectious COVID-19 corona...
# 3   Abstract The emerging global infectious COVID-...
# 4   Background Emerging and reemerging infectious ...
# 5   The novel coronavirus disease 2019 (COVID-19) ...
# 6   The recent emergence of a previously unknown c...
# 7   An automated statistical and error analysis of...
# 8   The outbreak of coronavirus disease 2019 (COVI...
# 9   BACKGROUND: Infodemiology (ie, information epi...
# 10  Cases of a novel coronavirus were first report...
# 11  Abstract A novel coronavirus, designated as SA...
# 12  The number of Covid-19 cases is increasing dra...
# 13  With the rapid development of mobile Internet ...
# 14  OBJECTIVE: To create an online resource that i...
# 15  The emergence of the novel betacoronavirus, re...
# 16  Effective public health response to COVID-19 r...
# 17  Transmissible gastroenteritis virus (TGEV) is ...
# 18  Information is the most potent protective weap...
# 19  BACKGROUND AND AIMS: Healthcare delivery requi...
# 20  While most countries implemented measures to r...
# 21  Abstract Background and aims Healthcare delive...
# 22  Background: The recent outbreak of infections ...
# 23  We describe fifteen major mutation events from...
# 24  [Image: see text] COVID-19 has spread globally...
# 25  We report here on antigens from the SARS-CoV-2...
# 26  We have developed an analysis pipeline to faci...
# 27  SARS-CoV-2 recently emerged, resulting a globa...
# 28  Rapid diagnostics, vaccines and therapeutics a...
# 29  At the time of writing this review, severe acu...
# 30  SARS-CoV-2, the causative agent of COVID-2019 ...
# 31  Background The burden and impact of healthcare...
# 32  Abstract The emergence of COVID-19 in South Ko...
# 33  The need for timely establishment of diagnosti...
# 34  The coronavirus disease 2019 pandemic has disp...
# 35  Control of the ongoing severe acute respirator...
# 36  We propose an efficient framework for genetic ...
# 37  The coronavirus disease 2019 (COVID-19) had sp...
# 38  The 2019 novel coronavirus (renamed SARS-CoV-2...
# 39                                                NaN
# 40  The current outbreak caused by novel coronavir...
# 41  In late December 2019, an emerging viral infec...
# 42  Platelets are anucleate cells in blood whose p...
# 43  The COVID-19 is a global pandemic. Its rapid d...
# 44  The pandemic novel coronavirus infection, Coro...
# 45  The 2019 novel coronavirus (2019-nCoV) outbrea...
# 46  Abstract The novel Coronavirus disease 2019 (C...
# 47  Currently, novel coronavirus disease 2019 (COV...
# 48  The key parameter that characterizes the trans...
# 49  Summary The coronavirus disease-2019 (COVID-19...
#
#                                                   url  \
# 0   https://doi.org/10.1093/bioinformatics/btaa145...
# 1           https://doi.org/10.1101/2020.01.31.928796
# 2              https://arxiv.org/pdf/2003.10965v1.pdf
# 3   https://api.elsevier.com/content/article/pii/S...
# 4           https://doi.org/10.1101/2020.04.08.031963
# 5           https://doi.org/10.1101/2020.04.25.060947
# 6   http://medrxiv.org/cgi/content/short/2020.05.0...
# 7         https://doi.org/10.1101/2020.03.31.20048827
# 8   https://www.ncbi.nlm.nih.gov/pubmed/32259477/;...
# 9   https://www.ncbi.nlm.nih.gov/pubmed/32250957/;...
# 10  https://www.ncbi.nlm.nih.gov/pubmed/32210236/;...
# 11  https://doi.org/10.1016/j.micinf.2020.05.001; ...
# 12             https://arxiv.org/pdf/2004.07977v1.pdf
# 13  http://medrxiv.org/cgi/content/short/2020.03.3...
# 14  https://doi.org/10.1093/jamia/ocaa071; https:/...
# 15  https://doi.org/10.1002/jmv.25773; https://www...
# 16  http://medrxiv.org/cgi/content/short/2020.05.0...
# 17  https://doi.org/10.1096/fj.201902455r; https:/...
# 18        https://doi.org/10.1101/2020.04.02.20051284
# 19  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 20  http://medrxiv.org/cgi/content/short/2020.05.1...
# 21  https://api.elsevier.com/content/article/pii/S...
# 22        https://doi.org/10.1101/2020.02.22.20025460
# 23          https://doi.org/10.1101/2020.04.21.054221
# 24  https://doi.org/10.1021/acsnano.0c02624; https...
# 25  http://medrxiv.org/cgi/content/short/2020.05.0...
# 26          https://doi.org/10.1101/2020.04.29.069054
# 27          https://doi.org/10.1101/2020.04.22.055897
# 28  https://doi.org/10.3390/jcm9030623; https://ww...
# 29  https://www.ncbi.nlm.nih.gov/pubmed/32397911/;...
# 30          https://doi.org/10.1101/2020.05.02.071811
# 31  http://medrxiv.org/cgi/content/short/2020.05.0...
# 32  https://api.elsevier.com/content/article/pii/S...
# 33  https://www.ncbi.nlm.nih.gov/pubmed/32156330/;...
# 34  https://www.ncbi.nlm.nih.gov/pubmed/32426754/;...
# 35  http://medrxiv.org/cgi/content/short/2020.04.2...
# 36          https://doi.org/10.1101/2020.04.07.030759
# 37  https://doi.org/10.1097/jcma.0000000000000325;...
# 38  https://doi.org/10.1371/journal.pone.0232391; ...
# 39  https://doi.org/10.1093/clinchem/hvaa038; http...
# 40          https://doi.org/10.1101/2020.01.30.926477
# 41          https://doi.org/10.1101/2020.05.03.074567
# 42  https://doi.org/10.7554/elife.52938; https://w...
# 43  https://doi.org/10.1007/s00455-020-10139-6; ht...
# 44  https://www.ncbi.nlm.nih.gov/pubmed/32276333/;...
# 45  https://doi.org/10.1093/cid/ciaa219; https://w...
# 46  https://www.ncbi.nlm.nih.gov/pubmed/32278175/;...
# 47             https://arxiv.org/pdf/2005.00662v3.pdf
# 48        https://doi.org/10.1101/2020.03.14.20035659
# 49  https://www.sciencedirect.com/science/article/...
#
#                                               authors  \
# 0   Cleemput, Sara; Dumon, Wim; Fonseca, Vagner; K...
# 1   Cleemput, Sara; Dumon, Wim; Fonseca, Vagner; A...
# 2                                     Yin, Changchuan
# 3                                     Yin, Changchuan
# 4   Holland, Mitchell; Negrón, Daniel; Mitchell, S...
# 5   Chen, Chen; Li, Jizhou; Di, Lin; Jing, Qiuyu; ...
# 6   Xavier, J.; Giovanetti, M.; Adelino, T.; Fonse...
# 7                                        Merrin, Jack
# 8   Kim, Young-Il; Kim, Seong-Gyu; Kim, Se-Mi; Kim...
# 9                                Mavragani, Amaryllis
# 10  Xu, Bo; Gutierrez, Bernardo; Mekaru, Sumiko; S...
# 11  Zhang, Naru; Li, Chaoqun; Hu, Yue; Li, Kangche...
# 12  Medeiros, Marcelo; Street, Alexandre; Valladao...
# 13  Shanlang, L.; Chao, M.; Ruofei, L.; Junpei, H....
# 14  Wissel, Benjamin D; Van Camp, P J; Kouril, Mic...
# 15  Giovanetti, Marta; Angeletti, Silvia; Benvenut...
# 16                                Lu, T.; Reis, B. Y.
# 17   Wang, Jian; Li, Yangyang; Wang, Shouyu; Liu, Fei
# 18  Segal, Eran; Zhang, Feng; Lin, Xihong; King, G...
# 19  Vaishya, Raju; Javaid, Mohd; Khan, Ibrahim Hal...
# 20               Wu, Y.; Huang, M.; Xie, G.; Chen, X.
# 21  Vaishya, Raju; Javaid, Mohd; Khan, Ibrahim Hal...
# 22  Hou, Tieying; Zeng, Weiqi; Yang, Minling; Chen...
# 23  Guan, Qingtian; Sadykov, Mukhtar; Nugmanova, R...
# 24  Udugama, Buddhisha; Kadhiresan, Pranav; Kozlow...
# 25  Chour, W.; Xu, A. M.; Ng, A. H. C.; Choi, J.; ...
# 26  Korber, B; Fischer, WM; Gnanakaran, S; Yoon, H...
# 27  Paden, Clinton R; Tao, Ying; Queen, Krista; Zh...
# 28  Pang, Junxiong; Wang, Min Xian; Ang, Ian Yi Ha...
# 29  Amawi, Haneen; Abu Deiab, Ghina'a I; A Aljabal...
# 30  Nelson-Sathi, Shijulal; Umasankar, PK; Sreekum...
# 31  Meredith, L. W.; Hamilton, W. L.; Warne, B.; H...
# 32                           Lee, David; Lee, Jaehong
# 33  Konrad, Regina; Eberle, Ute; Dangel, Alexandra...
# 34  Walkey, Allan J.; Kumar, Vishakha K.; Harhay, ...
# 35  Artesi, M.; Bontems, S.; Gobbels, P.; Franckh,...
# 36  Zhao, Zhengqiao; Sokhansanj, Bahrad A.; Rosen,...
# 37  Yuan, Eunice J.; Hsu, Chia-An; Lee, Wui-Chiang...
# 38  Randhawa, Gurjit S.; Soltysiak, Maximillian P....
# 39                    Lo, Y M Dennis; Chiu, Rossa W K
# 40  Xiong, Chenglong; Jiang, Lufang; Chen, Yue; Ji...
# 41  Laamarti, Meriem; Alouane, Tarek; Kartti, Soua...
# 42  Zhou, Yuqi; Yasumoto, Atsushi; Lei, Cheng; Hua...
# 43  Frajkova, Zofia; Tedla, Miroslav; Tedlova, Eva...
# 44  Yip, Cyril Chik-Yan; Ho, Chi-Chun; Chan, Jaspe...
# 45                                       Yi, Huiguang
# 46  Vellingiri, Balachandar; Jayaramayya, Kaavya; ...
# 47         Lee, Se Yoon; Lei, Bowen; Mallick, Bani K.
# 48                                          Tao, Yong
# 49  Atri, Deepak; Siddiqi, Hasan K.; Lang, Joshua;...
#
#                                                  text      Score
# 0   We are currently faced with a potential global...  22.262102
# 1   We are currently faced with a potential global...  21.113115
# 2   The novel coronavirus in humans, first discove...  20.446664
# 3   through nsp16 in all coronaviruses [8] . There...  20.102274
# 4   Using next generation sequencing, the whole ge...  18.086823
# 5   As of May 22, 2020, the ongoing COVID-19 viral...  16.010989
# 6   To date, more than 3.5 million cases of the di...  15.469203
# 7   Mathematics is essential to predict and contro...  15.163071
# 8   Coronaviruses (CoVs) are a large family of vir...  15.076527
# 9   In December 2019, Chinese researchers identifi...  14.799094
# 10  In December 2019 a number of novel coronavirus...  14.789665
# 11  In late December 2019, a pneumonia of unknown ...  14.670619
# 12  Being able to forecast accurately the number o...  14.261787
# 13  difficulty of epidemic prevention and control....  14.242511
# 14  As of April 13 th , the United States of Ameri...  14.233459
# 15  Coronaviruses (CoVs) are enveloped, positive‐s...  14.206456
# 16  Accurate real-time surveillance of local disea...  13.965029
# 17  Transmissible gastroenteritis virus (TGEV) is ...  13.855779
# 18  The CCC is a non-profit consortium open to any...  13.712987
# 19  In this worldwide health crisis, the medical i...  13.702983
# 20  As of 10 May 2020, there has been more than 4 ...  13.655200
# 21  In this worldwide health crisis, the medical i...  13.633815
# 22  Since the beginning of 2020, a surging number ...  13.571718
# 23  harbouring V483A and G476S mutations belong to...  13.516136
# 24  SARS-CoV-2 was first identified from patient s...  13.408559
# 25  In December 2019, an outbreak of unexplained p...  13.335027
# 26  KEYWORDS: COVID-19, pandemic, diversity, evolu...  13.234609
# 27  In December 2019, SARS-CoV-2, the etiological ...  13.217456
# 28  Since mid-December 2019 and as of early Februa...  13.172897
# 29  Coronaviruses (CoVs) belong to the genus Coron...  13.058392
# 30  COVID-19, the highly transmittable and pathoge...  12.998782
# 31  SARS-CoV-2 emerged in the human population in ...  12.910279
# 32  In early 2020, the world watched as a novel co...  12.835060
# 33  In connection with the ongoing outbreak of a n...  12.596926
# 34  The SCCM formed the Discovery, the Critical Ca...  12.544639
# 35  Coronavirus disease of 2019 (COVID-19) origina...  12.542551
# 36  For the aligned sequences, we merged the seque...  12.423850
# 37  The world was introduced to the coronavirus di...  12.373256
# 38  Coronaviruses are single-stranded positive-sen...  12.351881
# 39  In December 2019, a mysterious viral illness c...  12.340248
# 40  Coronaviruses (CoV) (order Nidovirales, family...  12.240991
# 41  We used Hyphy v2. 5.8 (13) to estimate synonym...  12.214958
# 42  Platelets are non-nucleated cells in blood who...  12.188046
# 43  The COVID-19 disease spread from Wuhan, China,...  12.177250
# 44  Coronaviruses are positive sense, single-stran...  12.141886
# 45  (shown as a pie chart node in Fig. 1 , see Tab...  12.099818
# 46  Most of the species under this head are enzoot...  12.090880
# 47  Since Thursday, March 26, 2020, the US leads t...  12.068897
# 48  In December, 2019, a cluster of pneumonia case...  12.053707
# 49  The coronavirus disease-2019 (COVID- 19) , a c...  12.039220

# %% [markdown]
# ### Q2: *Access to geographic and temporal diverse sample sets to understand geographic distribution and genomic differences, and determine whether there is more than one strain in circulation. Multi-lateral agreements such as the Nagoya Protocol could be leveraged.*

# %%
p = "Access to geographic and temporal diverse sample sets to understand geographic distribution and genomic differences, and determine whether there is more than one strain in circulation. Multi-lateral agreements such as the Nagoya Protocol could be leveraged."
res = searchAndGetAnswer(p)
res
# Out:
# 1/10
# 2/10
# 3/10
# 4/10
# 5/10
# 6/10
# 7/10
# 8/10
# 9/10
# 10/10
#                                                title  \
# 0  No-Test Medication Abortion: A Sample Protocol...
# 1  Evaluation of Rural Public Libraries to Addres...
# 2  Perfectionism and Perceived Control in Posttra...
# 3  Anatomic evidence shows that lymphatic drainag...
# 4  Quantifying antibody kinetics and RNA shedding...
# 5           Presence of SARS-Coronavirus-2 in sewage
# 6  Accelerated infection testing at scale: a prop...
# 7  Mobilization of Telepsychiatry in Response to ...
# 8      Genomic variance of the 2019‐nCoV coronavirus
# 9  Identification of IgG antibody response to SAR...
#
#                                             abstract Answer      Score  \
# 0                                                NaN  【  】   18.587669
# 1  Introduction: In the United States, access to ...  【  】   16.814598
# 2  In this study, we sought to examine associatio...  【  】   16.680524
# 3  Respiratory infections can result in intracran...  【  】   16.471302
# 4  Our ability to understand and mitigate the spr...  【  】   15.147414
# 5  In the current COVID-19 pandemic, a significan...  【  】   14.390560
# 6  In pandemics or epidemics, public health autho...  【  】   13.906085
# 7  The COVID-19 pandemic threatens to disrupt the...  【  】   13.785966
# 8  There is a rising global concern for the recen...  【  】   13.749903
# 9  Diagnostic testing and evaluation of patient i...  【  】   13.572998
#
#                                                  url  \
# 0  https://doi.org/10.1016/j.contraception.2020.0...
# 1  http://medrxiv.org/cgi/content/short/2020.05.2...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 3  https://www.sciencedirect.com/science/article/...
# 4  http://medrxiv.org/cgi/content/short/2020.05.1...
# 5  http://medrxiv.org/cgi/content/short/2020.03.2...
# 6             https://arxiv.org/pdf/2003.13282v1.pdf
# 7  https://doi.org/10.1007/s10488-020-01044-z; ht...
# 8  https://www.ncbi.nlm.nih.gov/pubmed/32027036/;...
# 9  http://medrxiv.org/cgi/content/short/2020.05.0...
#
#                                              authors
# 0  Raymond, Elizabeth G.; Grossman, Daniel; Mark,...
# 1  DeGuzman, P. B.; Siegfried, Z. C.; Leimkuhler,...
# 2  Molnar, Danielle S.; Flett, Gordon L.; Hewitt,...
# 3  Elham, Elzat; Wumaier, Reziya; Wang, Chengji; ...
# 4  Borremans, B.; Gamble, A.; Prager, K. C.; Helm...
# 5  Medema, G.; Heijnen, L.; Elsinga, G.; Italiaan...
# 6                   Jain, Tarun; Jain, Bijendra Nath
# 7  Kannarkat, Jacob T.; Smith, Noah N.; McLeod-Br...
# 8              Ceraolo, Carmine; Giorgi, Federico M.
# 9  McAndrews, K. M.; Dowlatshahi, D. P.; Hensel, ...

# %% [markdown]
# ### Q3: *Evidence that livestock could be infected (e.g., field surveillance, genetic sequencing, receptor binding) and serve as a reservoir after the epidemic appears to be over.*
# * Evidence of whether farmers are infected, and whether farmers could have played a role in the origin.
# * Surveillance of mixed wildlife- livestock farms for SARS-CoV-2 and other coronaviruses in Southeast Asia.
# * Experimental infections to test host range for this pathogen.

# %%
p = '''
Evidence that livestock could be infected (e.g., field surveillance, genetic sequencing, receptor binding) and serve as a reservoir after the epidemic appears to be over.
Evidence of whether farmers are infected, and whether farmers could have played a role in the origin.
Surveillance of mixed wildlife- livestock farms for SARS-CoV-2 and other coronaviruses in Southeast Asia.
Experimental infections to test host range for this pathogen.
'''
res = searchAndGetAnswer(p)
res
# Out:
# No valid answers found.
#                                                 title  \
# 0   Coronavirus surveillance of wildlife in the La...
# 1   SARS-CoV-2 spike protein predicted to form sta...
# 2   Spillover of SARS-CoV-2 into novel wild hosts ...
# 3   Are pangolins the intermediate host of the 201...
# 4   A potential role for integrins in host cell en...
# 5   Hypothesis: angiotensin-converting enzyme inhi...
# 6   Proteolytic cleavage of the SARS-CoV-2 spike p...
# 7   Predicting wildlife hosts of betacoronaviruses...
# 8   SARS-CoV-2, an evolutionary perspective of int...
# 9   Use of the informational spectrum methodology ...
# 10  The Story behind COVID-19: Animal Diseases at ...
# 11  Comparison of SARS-CoV-2 spike protein binding...
# 12  SARS-CoV-2: an Emerging Coronavirus that Cause...
# 13  Cross‐species transmission of the newly identi...
# 14  A pneumonia outbreak associated with a new cor...
# 15  Structural Basis for Potent Neutralization of ...
# 16  Isolation, quarantine, social distancing and c...
# 17  Potential host range of multiple SARS-like cor...
# 18  Monoclonal antibodies for the S2 subunit of sp...
# 19  Are pangolins the intermediate host of the 201...
# 20  Interactions of coronaviruses with ACE2, angio...
# 21  Failed detection of the full-length genome of ...
# 22  Genetic analysis of the novel SARS-CoV-2 host ...
# 23  Comparative seasonalities of influenza A, B an...
# 24  Emergence of SARS-CoV-2 through Recombination ...
# 25  Receptor Recognition by the Novel Coronavirus ...
# 26  Evidence of recombination in coronaviruses imp...
# 27  The Potential Role of Th17 Immune Responses in...
# 28  Structural Basis for Potent Neutralization of ...
# 29  Detection of novel coronaviruses in bats in My...
# 30  Diarrhea may be underestimated: a missing link...
# 31  SARS‐CoV‐2, an evolutionary perspective of int...
# 32  Analyses of spike protein from first deposited...
# 33  A novel bat coronavirus reveals natural insert...
# 34  Emerging novel coronavirus (2019-nCoV)—current...
# 35  False-Negative Results of Real-Time Reverse-Tr...
# 36  No evidence for allelic association between Co...
# 37  Development of a rapid test kit for SARS-CoV-2...
# 38  Genome-wide data inferring the evolution and p...
# 39  Genetic Variability of Human Angiotensin-Conve...
# 40  The COVID-19 Host Genetics Initiative, a globa...
# 41  COVID-19: is there a role for immunonutrition,...
# 42  “Amantadine disrupts lysosomal gene expression...
# 43            Zoonotic origins of human coronaviruses
# 44  Heterogeneous expression of the SARS-Coronavir...
# 45  Susceptible supply limits the role of climate ...
# 46  Could India be the origin of next COVID-19 lik...
# 47  “Amantadine disrupts lysosomal gene expression...
# 48  Deep phylogenetic analysis of Orthocoronavirin...
# 49  Prediction analysis of SARS-COV-2 entry in Liv...
#
#                                              abstract  \
# 0   Coronaviruses can become zoonotic as in the ca...
# 1   SARS-CoV-2 has a zoonotic origin and was trans...
# 2   Abstract There is evidence that the current ou...
# 3   The outbreak of 2019-nCoV pneumonia (COVID-19)...
# 4   • Integrin may act as an alternative receptor ...
# 5   Intravenous infusions of angiotensin-convertin...
# 6   Abstract Severe acute respiratory syndrome cor...
# 7   Despite massive investment in research on rese...
# 8   The emergence of SARS-CoV-2 has resulted in mo...
# 9   A novel coronavirus recently identified in Wuh...
# 10  A number of virological, epidemiological and e...
# 11  The emergence of a novel coronavirus, SARS-CoV...
# 12  An ongoing outbreak of pneumonia caused by a n...
# 13  The current outbreak of viral pneumonia in the...
# 14  Since the outbreak of severe acute respiratory...
# 15  Summary Coronaviruses make use of a large enve...
# 16  Public health measures were decisive in contro...
# 17  The severe acute respiratory syndrome coronavi...
# 18  The emergence of a novel coronavirus, SARS-CoV...
# 19  The outbreak of a novel corona Virus Disease 2...
# 20  The rapid spread of a novel coronavirus, sever...
# 21  Over 10 percent of recovered and discharged pa...
# 22  The infection coronavirus disease 2019 (COVID-...
# 23  Comparative seasonalities of influenza A, B an...
# 24  COVID-19 has become a global pandemic caused b...
# 25  Recently, a novel coronavirus (2019-nCoV) has ...
# 26  A novel coronavirus (nCoV-2019) was the cause ...
# 27  Increasing evidence points to host Th17 inflam...
# 28  The pathogenic Middle East respiratory syndrom...
# 29  The recent emergence of bat-borne zoonotic vir...
# 30  The outbreak of pneumonia caused by the 2019 N...
# 31  The emergence of SARS‐CoV‐2 has resulted in ne...
# 32  India has recently started sequencing SARS-CoV...
# 33  The unprecedented epidemic of pneumonia caused...
# 34  Coronaviruses are the well-known cause of seve...
# 35  The epidemic of 2019 novel coronavirus, later ...
# 36  Background: Coronaviruses (CoV) are a large fa...
# 37  We present an example of applying ‘need-driven...
# 38  Since December 2019, coronavirus disease 2019 ...
# 39  There appears to be large regional variations ...
# 40                                                NaN
# 41  In late December 2019 severe acute respiratory...
# 42  SARS-coronavirus 2 is the causal agent of the ...
# 43  Mutation and adaptation have driven the co-evo...
# 44  Rationale Zoonotically transmitted coronavirus...
# 45  Preliminary evidence suggests that climate may...
# 46  Abstract The COVID-19 global pandemic is not e...
# 47  Abstract SARS-coronavirus 2 is the causal agen...
# 48  The outbreak of severe acute respiratory syndr...
# 49  Interaction between spike protein of SARS-CoV-...
#
#                                                   url  \
# 0           https://doi.org/10.1101/2020.04.22.056218
# 1           https://doi.org/10.1101/2020.05.01.072371
# 2   https://api.elsevier.com/content/article/pii/S...
# 3           https://doi.org/10.1101/2020.02.18.954628
# 4   https://doi.org/10.1016/j.antiviral.2020.10475...
# 5   https://www.ncbi.nlm.nih.gov/pubmed/32186711/;...
# 6   https://api.elsevier.com/content/article/pii/S...
# 7           https://doi.org/10.1101/2020.05.22.111344
# 8           https://doi.org/10.1101/2020.03.21.001933
# 9   https://www.ncbi.nlm.nih.gov/pubmed/32419926/;...
# 10                https://doi.org/10.1017/err.2020.45
# 11          https://doi.org/10.1101/2020.05.08.084061
# 12  https://doi.org/10.7150/ijbs.45053; https://ww...
# 13  https://www.ncbi.nlm.nih.gov/pubmed/31967321/;...
# 14  https://www.ncbi.nlm.nih.gov/pubmed/32015507/;...
# 15  https://doi.org/10.1016/j.cell.2020.04.031; ht...
# 16  https://www.ncbi.nlm.nih.gov/pubmed/32052841/;...
# 17          https://doi.org/10.1101/2020.04.10.032342
# 18          https://doi.org/10.1101/2020.03.06.980037
# 19  https://www.ncbi.nlm.nih.gov/pubmed/32407364/;...
# 20  https://www.ncbi.nlm.nih.gov/pubmed/32341442/;...
# 21        https://doi.org/10.1101/2020.03.27.20043299
# 22          https://doi.org/10.1101/2020.04.23.057190
# 23  https://www.sciencedirect.com/science/article/...
# 24          https://doi.org/10.1101/2020.03.20.000885
# 25  https://doi.org/10.1128/jvi.00127-20; https://...
# 26          https://doi.org/10.1101/2020.02.07.939207
# 27  https://doi.org/10.1016/j.micinf.2020.04.005; ...
# 28          https://doi.org/10.1101/2020.03.26.010165
# 29  https://www.ncbi.nlm.nih.gov/pubmed/32271768/;...
# 30  http://medrxiv.org/cgi/content/short/2020.02.0...
# 31                  https://doi.org/10.1111/eva.12980
# 32          https://doi.org/10.1101/2020.04.28.066985
# 33          https://doi.org/10.1101/2020.03.02.974139
# 34  https://www.ncbi.nlm.nih.gov/pubmed/32036774/;...
# 35  https://doi.org/10.3348/kjr.2020.0146; https:/...
# 36  http://medrxiv.org/cgi/content/short/2020.05.2...
# 37  https://doi.org/10.1007/s42242-020-00075-7; ht...
# 38          https://doi.org/10.1101/2020.03.04.976662
# 39          https://doi.org/10.1101/2020.04.14.041434
# 40  https://www.ncbi.nlm.nih.gov/pubmed/32404885/;...
# 41  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 42          https://doi.org/10.1101/2020.04.05.026187
# 43  https://doi.org/10.7150/ijbs.45472; https://ww...
# 44          https://doi.org/10.1101/2020.04.22.056127
# 45        https://doi.org/10.1101/2020.04.03.20052787
# 46  https://www.sciencedirect.com/science/article/...
# 47  https://www.ncbi.nlm.nih.gov/pubmed/32361028/;...
# 48          https://doi.org/10.1101/2020.05.12.091199
# 49          https://doi.org/10.1101/2020.05.08.084327
#
#                                               authors  \
# 0   McIver, David J.; Silithammavong, Soubanh; The...
# 1   Lam, SD; Bordin, N; Waman, VP; Scholes, HM; As...
# 2                 Franklin, Alan B.; Bevins, Sarah N.
# 3   Liu, Ping; Jiang, Jing-Zhe; Wan, Xiu-Feng; Hua...
# 4   Sigrist, Christian JA; Bridge, Alan; Le Mercie...
# 5                                       Diaz, James H
# 6   Jaimes, Javier A.; Millet, Jean K.; Whittaker,...
# 7   Becker, Daniel J.; Albery, Gregory F.; Sjodin,...
# 8   Armijos-Jaramillo, Vinicio; Yeager, Justin; Mu...
# 9   Veljkovic, Veljko; Vergara-Alert, Júlia; Segal...
# 10            DE SADELEER, Nicolas; GODFROID, Jacques
# 11  Zhai, Xiaofeng; Sun, Jiumeng; Yan, Ziqing; Zha...
# 12                                         Zheng, Jun
# 13  Ji, Wei; Wang, Wei; Zhao, Xiaofang; Zai, Junji...
# 14  Zhou, Peng; Yang, Xing-Lou; Wang, Xian-Guang; ...
# 15  Wrapp, Daniel; De Vlieger, Dorien; Corbett, Ki...
# 16                     Wilder-Smith, A; Freedman, D O
# 17  Li, Yujun; Wang, Haimin; Tang, Xiaojuan; Ma, D...
# 18  Zheng, Zhiqiang; Monteil, Vanessa M.; Maurer-S...
# 19  Liu, Ping; Jiang, Jing-Zhe; Wan, Xiu-Feng; Hua...
# 20                          Kai, Hisashi; Kai, Mamiko
# 21  Hu, Fengyu; Chen, Fengjuan; Wang, Yaping; Xu, ...
# 22  Russo, Roberta; Andolfo, Immacolata; Lasorsa, ...
# 23  Liu, Yang; Lam, Tommy TY; Lai, Florence YL; Kr...
# 24  Li, Xiaojun; Giorgi, Elena E.; Marichann, Manu...
# 25  Wan, Yushun; Shang, Jian; Graham, Rachel; Bari...
# 26  Wong, Matthew C.; Javornik Cregeen, Sara J.; A...
# 27  Hotez, Peter J.; Bottazzi, Maria Elena; Corry,...
# 28  Wrapp, Daniel; De Vlieger, Dorien; Corbett, Ki...
# 29  Valitutto, Marc T.; Aung, Ohnmar; Tun, Kyaw Ya...
# 30  Liang, W.; Rao, S.; Xiao, C.; Lin, Z.; Zhang, ...
# 31  Armijos‐Jaramillo, Vinicio; Yeager, Justin; Mu...
# 32  Begum, Feroza; Mukherjee, Debica; Thagriki, Dl...
# 33  Zhou, Hong; Chen, Xing; Hu, Tao; Li, Juan; Son...
# 34  Malik, Yashpal Singh; Sircar, Shubhankar; Bhat...
# 35  Li, Dasheng; Wang, Dawei; Dong, Jianping; Wang...
# 36  Novelli, A.; Biancolella, M.; Borgiani, P.; Co...
# 37  Cui, Zhanfeng; Chang, Hong; Wang, Hui; Lim, Bo...
# 38  Fang, Bin; Liu, Linlin; Yu, Xiao; Li, Xiang; Y...
# 39              Li, Quan; Cao, Zanxia; Rahman, Proton
# 40                                                NaN
# 41                  Derbyshire, Emma; Delange, Joanne
# 42  Smieszek, Sandra P.; Przychodzen, Bart P; Poly...
# 43  Ye, Zi-Wei; Yuan, Shuofeng; Yuen, Kit-San; Fun...
# 44  Bezara, Miguel Ortiz; Thurman, Andrew; Pezzulo...
# 45  Baker, Rachel E.; Yang, Wenchang; Vecchi, Gabr...
# 46                                     Minhas, Sachin
# 47  Smieszek, Sandra P.; Przychodzen, Bart P; Poly...
# 48                    Sharma, Amresh Kumar; Som, Anup
# 49  Praharaj, Manas Ranjan; Garg, Priyanka; Nabi K...
#
#                                                  text      Score
# 0   The latest coronavirus (CoV) outbreak in human...  30.306554
# 1   Severe acute respiratory syndrome coronavirus ...  29.467318
# 2   J o u r n a l P r e -p r o o f 2 infected huma...  26.276919
# 3   In December 2019, there was an outbreak of pne...  25.001637
# 4   Since December 2019, a novel coronavirus (nCoV...  23.883754
# 5   Highlight Intravenous infusions of angiotensin...  23.743547
# 6   Since December 2019, human infections by a nov...  23.606242
# 7   sampling bias and can only make predictions fo...  23.308656
# 8   The recent emergence of the novel SARS coronav...  22.974869
# 9   Fears are mounting worldwide over the cross-bo...  22.492407
# 10  Today, the world is facing the ongoing COVID-1...  22.325828
# 11  infection of the respective animal. Some ACE2 ...  21.729573
# 12  Since December 2019, an increasing number of p...  21.488953
# 13  China has been the epicenter of emerging and r...  21.253602
# 14  Coronaviruses have caused two large-scale pand...  19.634429
# 15  Coronaviruses are enveloped, positive-sense RN...  19.554057
# 16  The novel coronavirus (2019-nCoV) that emerged...  19.552576
# 17  Two subgroups of coronaviruses, including alph...  19.498712
# 18  S1 subunit being responsible for attachment to...  19.405478
# 19  In December 2019, there was an outbreak of pne...  19.247204
# 20  A novel coronavirus, named severe acute respir...  19.016471
# 21  The novel coronavirus (SARS-CoV-2) infection s...  18.973756
# 22  In December 2019 a new infectious respiratory ...  18.915290
# 23  Dear Editor,\nWe read with interest the recent...  18.860648
# 24  The severe respiratory disease COVID-19 was fi...  18.853971
# 25  A novel coronavirus (2019-nCoV) from Wuhan, Ch...  18.789114
# 26  An outbreak of respiratory illness caused by a...  18.610622
# 27  COVID19 caused by the SARS-2 coronavirus (SARS...  18.203589
# 28  The pathogenic Middle East respiratory syndrom...  18.150488
# 29  Infectious diseases are considered to be “emer...  18.096310
# 30  same cell entry receptor ACE2 with that of SAR...  18.081031
# 31  The recent emergence of the novel SARS coronav...  17.867609
# 32  SARS-CoV2 (a member of Coronaviruses) outbreak...  17.846854
# 33  The unprecedented epidemic of pneumonia caused...  17.844430
# 34  Coronaviruses (CoVs) are well-known causes of ...  17.775618
# 35  At the end of December 2019, pneumonia of unkn...  17.670776
# 36  Coronaviruses (CoV) are a large family of viru...  17.622174
# 37  The COVID-19 pandemic caught almost every coun...  17.576274
# 38  On this analysis technique, to precisely decod...  17.410927
# 39  As of March 24, 2020, the worldwide tracking f...  17.363501
# 40  The COVID-19 host genetics initiative is a bot...  17.270880
# 41  Coronaviruses are important pathogens to anima...  17.161800
# 42  Recently a novel type of highly virulent beta-...  17.066529
# 43  Coronaviruses (CoVs) belong to the family Coro...  17.014703
# 44  infection can be fatal, with the risk for incr...  16.993752
# 45  The SARS-CoV-2 pandemic represents a generatio...  16.963317
# 46  It all started from a wet market in Wuhan, the...  16.903808
# 47  Recently a novel type of highly virulent beta-...  16.896807
# 48  Coronaviruses are single-stranded RNA virus of...  16.787652
# 49  Three large-scale disease outbreaks during the...  16.754176

# %% [markdown]
# ### Q4: *Animal host(s) and any evidence of continued spill-over to humans*

# %%
p = '''
Animal host(s) and any evidence of continued spill-over to humans
'''
res = searchAndGetAnswer(p)
res
# Out:
# No valid answers found.
#                                                 title  \
# 0   Spillover of SARS-CoV-2 into novel wild hosts ...
# 1   Are pangolins the intermediate host of the 201...
# 2   Are pangolins the intermediate host of the 201...
# 3   Exceptional diversity and selection pressure o...
# 4   COVID-19: Epidemiology, Evolution, and Cross-D...
# 5   Severe acute respiratory syndrome-related coro...
# 6              Horses as a Crucial Part of One Health
# 7   Emerging novel coronavirus (2019-nCoV)—current...
# 8   The species Severe acute respiratory syndrome-...
# 9   Emergence of SARS-CoV-2 through Recombination ...
# 10  Detection of novel coronaviruses in bats in My...
# 11  A tug-of-war between severe acute respiratory ...
# 12            A deadly spillover: SARS-CoV-2 outbreak
# 13  COVID-19: the First Documented Coronavirus Pan...
# 14  Coronaviruses: a paradigm of new emerging zoon...
# 15  Can the Coronavirus Disease 2019 (COVID-19) Af...
# 16  Personal protective equipment (PPE) for vitreo...
# 17  Global mapping of landscape fragmentation, hum...
# 18  Potential host range of multiple SARS-like cor...
# 19  A novel bat coronavirus closely related to SAR...
# 20            Zoonotic origins of human coronaviruses
# 21  Ecological processes underlying the emergence ...
# 22  Origin and Evolution of the 2019 Novel Coronav...
# 23  Interactions of coronaviruses with ACE2, angio...
# 24  Role of changes in SARS-CoV-2 spike protein in...
# 25  Predicting the angiotensin converting enzyme 2...
# 26  Human coronaviruses with emphasis on the COVID...
# 27  Bioaerosol Sampling at a Live Animal Market in...
# 28  Extracellular superoxide dismutase, a molecula...
# 29  Deep phylogenetic analysis of Orthocoronavirin...
# 30  Evolutionary origins of the SARS-CoV-2 sarbeco...
# 31  Development of remdesivir repositioning as a n...
# 32  VOLATILITY SPILLOVER AROUND PRICE LIMITS IN AN...
# 33  Receptor Recognition by the Novel Coronavirus ...
# 34  Identification of 2019-nCoV related coronaviru...
# 35  Susceptibility of ferrets, cats, dogs, and oth...
# 36  Susceptibility of ferrets, cats, dogs, and dif...
# 37  Structural and biochemical characterization of...
# 38  Structural and biochemical characterization of...
# 39  A Multibasic Cleavage Site in the Spike Protei...
# 40  Comparative computational analysis of SARS-CoV...
# 41  Synergistic China–US Ecological Research is Es...
# 42  A new coronavirus associated with human respir...
# 43  SARS‐CoV‐2 spike protein favors ACE2 from Bovi...
# 44  Novel Immunoglobulin Domain Proteins Provide I...
# 45  Novel NGS Pipeline for Virus Discovery from a ...
# 46                      The hard problem of AI rights
# 47  Broad and differential animal ACE2 receptor us...
# 48  Pangolins Lack IFIH1/MDA5, a Cytoplasmic RNA S...
# 49                           New Virus, New Challenge
#
#                                              abstract  \
# 0   Abstract There is evidence that the current ou...
# 1   The outbreak of 2019-nCoV pneumonia (COVID-19)...
# 2   The outbreak of a novel corona Virus Disease 2...
# 3   Pandemics originating from pathogen transmissi...
# 4   The recent outbreak of COVID-19 in Wuhan turne...
# 5   The present outbreak of lower respiratory trac...
# 6   One Health (OH) is a crucial concept, where th...
# 7   Coronaviruses are the well-known cause of seve...
# 8   The present outbreak of a coronavirus-associat...
# 9   COVID-19 has become a global pandemic caused b...
# 10  The recent emergence of bat-borne zoonotic vir...
# 11  World Health Organization has declared the ong...
# 12                                                NaN
# 13  The novel human coronavirus disease COVID-19 h...
# 14  A novel type of coronavirus (2019-nCoV) infect...
# 15  In December 2019, a novel coronavirus (CoV) ep...
# 16  SARS-CoV-2 is the recently discovered virus wh...
# 17  Everyone wants to know when the next pandemic ...
# 18  The severe acute respiratory syndrome coronavi...
# 19  Summary The unprecedented pandemic of pneumoni...
# 20  Mutation and adaptation have driven the co-evo...
# 21  Pathogens originating from wildlife (zoonoses)...
# 22  As of today, the intermediate host of 2019-nCo...
# 23  The rapid spread of a novel coronavirus, sever...
# 24  Many human viral diseases are a consequence of...
# 25  Abstract SARS-CoV-2, the newly identified huma...
# 26  Human coronaviruses are known as respiratory p...
# 27  From October to December 2018, periodic bioaer...
# 28  Extracellular superoxide dismutase (EcSOD) is ...
# 29  The outbreak of severe acute respiratory syndr...
# 30  There are outstanding evolutionary questions o...
# 31  Severe acute respiratory syndrome coronavirus ...
# 32  Abstract The intraday volatility effects of pr...
# 33  Recently, a novel coronavirus (2019-nCoV) has ...
# 34  The ongoing outbreak of viral pneumonia in Chi...
# 35  Severe acute respiratory syndrome coronavirus ...
# 36  Severe acute respiratory syndrome coronavirus ...
# 37  Summary The ongoing global pandemic of coronav...
# 38  The ongoing global pandemic of coronavirus dis...
# 39  Summary The pandemic coronavirus SARS-CoV-2 th...
# 40  Abstract Several research lines are currently ...
# 41  The risk of a zoonotic pandemic disease threat...
# 42  Emerging infectious diseases, such as severe a...
# 43  Severe acute respiratory syndrome coronavirus ...
# 44  A novel coronavirus (SARS-CoV-2) is the causat...
# 45  The study of the microbiome data holds great p...
# 46  In the past few years, the subject of AI right...
# 47  The COVID-19 pandemic has caused an unpreceden...
# 48  Zoonotic infections are an imminent threat to ...
# 49  The ongoing COVID-19 pandemic has made us to c...
#
#                                                   url  \
# 0   https://api.elsevier.com/content/article/pii/S...
# 1           https://doi.org/10.1101/2020.02.18.954628
# 2   https://www.ncbi.nlm.nih.gov/pubmed/32407364/;...
# 3           https://doi.org/10.1101/2020.04.20.051656
# 4   https://www.ncbi.nlm.nih.gov/pubmed/32359479/;...
# 5           https://doi.org/10.1101/2020.02.07.937862
# 6   https://www.ncbi.nlm.nih.gov/pubmed/32121327/;...
# 7   https://www.ncbi.nlm.nih.gov/pubmed/32036774/;...
# 8   https://doi.org/10.1038/s41564-020-0695-z; htt...
# 9           https://doi.org/10.1101/2020.03.20.000885
# 10  https://www.ncbi.nlm.nih.gov/pubmed/32271768/;...
# 11  https://doi.org/10.1080/22221751.2020.1736644;...
# 12  https://www.ncbi.nlm.nih.gov/pubmed/32321324/;...
# 13  https://www.ncbi.nlm.nih.gov/pubmed/32387617/;...
# 14  https://doi.org/10.1093/femspd/ftaa006; https:...
# 15  https://doi.org/10.1080/09273948.2020.1738501;...
# 16  https://www.ncbi.nlm.nih.gov/pubmed/32398849/;...
# 17  https://doi.org/10.1007/s10460-020-10104-x; ht...
# 18          https://doi.org/10.1101/2020.04.10.032342
# 19  https://api.elsevier.com/content/article/pii/S...
# 20  https://doi.org/10.7150/ijbs.45472; https://ww...
# 21          https://doi.org/10.1101/2020.04.24.057430
# 22  https://www.ncbi.nlm.nih.gov/pubmed/32011673/;...
# 23  https://www.ncbi.nlm.nih.gov/pubmed/32341442/;...
# 24  https://www.ncbi.nlm.nih.gov/pubmed/32210742/;...
# 25  https://www.ncbi.nlm.nih.gov/pubmed/32199943/;...
# 26  https://www.ncbi.nlm.nih.gov/pubmed/32399479/;...
# 27  https://doi.org/10.1093/ofid/ofaa134; https://...
# 28  https://doi.org/10.1016/j.redox.2020.101508; h...
# 29          https://doi.org/10.1101/2020.05.12.091199
# 30          https://doi.org/10.1101/2020.03.30.015008
# 31  https://doi.org/10.1080/07391102.2020.1767210;...
# 32  https://www.sciencedirect.com/science/article/...
# 33  https://doi.org/10.1128/jvi.00127-20; https://...
# 34          https://doi.org/10.1101/2020.02.13.945485
# 35  https://doi.org/10.1126/science.abb7015; https...
# 36          https://doi.org/10.1101/2020.03.30.015347
# 37  https://www.sciencedirect.com/science/article/...
# 38          https://doi.org/10.1101/2020.04.23.057265
# 39  https://www.sciencedirect.com/science/article/...
# 40  https://www.ncbi.nlm.nih.gov/pubmed/32302675/;...
# 41  https://doi.org/10.1007/s10393-020-01471-2; ht...
# 42  https://www.ncbi.nlm.nih.gov/pubmed/32015508/;...
# 43  https://doi.org/10.1002/jmv.25817; https://www...
# 44          https://doi.org/10.1101/2020.03.04.977736
# 45          https://doi.org/10.1101/2020.05.07.082107
# 46  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 47          https://doi.org/10.1101/2020.04.19.048710
# 48           https://doi.org/10.3389/fimmu.2020.00939
# 49  https://www.sciencedirect.com/science/article/...
#
#                                               authors  \
# 0                 Franklin, Alan B.; Bevins, Sarah N.
# 1   Liu, Ping; Jiang, Jing-Zhe; Wan, Xiu-Feng; Hua...
# 2   Liu, Ping; Jiang, Jing-Zhe; Wan, Xiu-Feng; Hua...
# 3      Frank, Hannah K.; Enard, David; Boyd, Scott D.
# 4   Sun, Jiumeng; He, Wan-Ting; Wang, Lifang; Lai,...
# 5   Gorbalenya, Alexander E.; Baker, Susan C.; Bar...
# 6   Lönker, Nelly Sophie; Fechner, Kim; Abd El Wah...
# 7   Malik, Yashpal Singh; Sircar, Shubhankar; Bhat...
# 8                                                 NaN
# 9   Li, Xiaojun; Giorgi, Elena E.; Marichann, Manu...
# 10  Valitutto, Marc T.; Aung, Ohnmar; Tun, Kyaw Ya...
# 11  Fung, Sin-Yee; Yuen, Kit-San; Ye, Zi-Wei; Chan...
# 12  Mori, Mattia; Capasso, Clemente; Carta, Fabriz...
# 13         Liu, Yen-Chin; Kuo, Rei-Lin; Shih, Shin-Ru
# 14  Salata, Cristiano; Calistri, Arianna; Parolin,...
# 15                        Seah, Ivan; Agrawal, Rupesh
# 16  Chandra, Aman; Haynes, Richard; Burdon, Michae...
# 17                            Bloomfield, Laura S. P.
# 18  Li, Yujun; Wang, Haimin; Tang, Xiaojuan; Ma, D...
# 19  Zhou, Hong; Chen, Xing; Hu, Tao; Li, Juan; Son...
# 20  Ye, Zi-Wei; Yuan, Shuofeng; Yuen, Kit-San; Fun...
# 21  Guth, Sarah; Hanley, Kathryn; Althouse, Benjam...
# 22  Zhang, Liangsheng; Shen, Fu-ming; Chen, Fei; L...
# 23                          Kai, Hisashi; Kai, Mamiko
# 24  Ortega, Joseph Thomas; Serrano, Maria Luisa; P...
# 25  Qiu, Ye; Zhao, Yuan-Bo; Wang, Qiong; Li, Jin-Y...
# 26    Bahadur, Saraj; Long, Wenxing; Shuaib, Muhammad
# 27  Wang, Xinye; Bailey, Emily S; Qi, Xian; Yu, Hu...
# 28                    Yan, Zhen; Spaulding, Hannah R.
# 29                    Sharma, Amresh Kumar; Som, Anup
# 30  Boni, Maciej F; Lemey, Philippe; Jiang, Xiaowe...
# 31  Babadaei, Mohammad Mahdi Nejadi; Hasan, Anwaru...
# 32  Aktas, Osman Ulas; Kryzanowski, Lawrence; Zhan...
# 33  Wan, Yushun; Shang, Jian; Graham, Rachel; Bari...
# 34  Lam, Tommy Tsan-Yuk; Shum, Marcus Ho-Hin; Zhu,...
# 35  Shi, Jianzhong; Wen, Zhiyuan; Zhong, Gongxun; ...
# 36  Shi, Jianzhong; Wen, Zhiyuan; Zhong, Gongxun; ...
# 37  Peng, Qi; Peng, Ruchao; Yuan, Bin; Zhao, Jingr...
# 38  Peng, Qi; Peng, Ruchao; Yuan, Bin; Zhao, Jingr...
# 39  Hoffmann, Markus; Kleine-Weber, Hannah; Pöhlma...
# 40  Tilocca, Bruno; Soggiu, Alessio; Sanguinetti, ...
# 41  Smiley Evans, Tierra; Shi, Zhengli; Boots, Mic...
# 42  Wu, Fan; Zhao, Su; Yu, Bin; Chen, Yan-Mei; Wan...
# 43  Luan, Junwen; Jin, Xiaolu; Lu, Yue; Zhang, Lei...
# 44  Tan, Yongjun; Schneider, Theresa; Leong, Matth...
# 45  Plyusnin, Ilya; Kant, Ravi; Jääskeläinen, Anne...
# 46                                 Andreotta, Adam J.
# 47  Zhao, Xuesen; Chen, Danying; Szabla, Robert; Z...
# 48  Fischer, Heinz; Tschachler, Erwin; Eckhart, Le...
# 49                                            Shi, Yi
#
#                                                  text      Score
# 0   J o u r n a l P r e -p r o o f 2 infected huma...  22.379831
# 1   In December 2019, there was an outbreak of pne...  15.671288
# 2   In December 2019, there was an outbreak of pne...  14.773573
# 3   because studies only examine a small subset of...  14.143423
# 4   In December 2019, a cluster of pneumonia with ...  12.735855
# 5   Is the outbreak of an infectious disease cause...  12.127306
# 6   One Health (OH) is a holistic approach which d...  12.061077
# 7   Coronaviruses (CoVs) are well-known causes of ...  11.823325
# 8   Understanding the cause of a specific disease ...  11.678412
# 9   The severe respiratory disease COVID-19 was fi...  11.136798
# 10  Infectious diseases are considered to be “emer...  11.029762
# 11  Avian infectious bronchitis virus was the firs...  11.006490
# 12  Coronaviruses (CoV) are a family of viruses th...  10.810611
# 13  Currently, people all over the world have been...  10.800136
# 14  Coronaviruses (CoVs) are important pathogens f...  10.766239
# 15  CoVs belong to the subfamily Coronavirinae, in...  10.757793
# 16  SARS-CoV-2 is the recently discovered virus wh...  10.681540
# 17  Everyone wants to know when the next pandemic ...  10.462016
# 18  Two subgroups of coronaviruses, including alph...  10.385967
# 19  novel bat coronavirus novel bat coronavirus no...  10.159164
# 20  Coronaviruses (CoVs) belong to the family Coro...  10.076111
# 21  Humans have frequently enabled pathogens to ov...   9.767405
# 22  To the Editor-The 2019 novel coronavirus disea...   9.487336
# 23  A novel coronavirus, named severe acute respir...   9.474802
# 24  Severe Acute Respiratory Syndrome Coronavirus ...   9.440461
# 25  The aa sequences of ACE2s of Homo sapiens (hum...   9.105582
# 26  Coronaviruses are positive-standard enveloped ...   9.105582
# 27  Bioaerosol samples were obtained from a small ...   9.099620
# 28  Oxygen is indispensable for life; however, und...   8.950877
# 29  Coronaviruses are single-stranded RNA virus of...   8.895972
# 30  In December 2019, a cluster of pneumonia cases...   8.855392
# 31  The new coronavirus (CoV), known as Severe Acu...   8.771147
# 32  We gratefully acknowledge financial support fr...   8.706396
# 33  A novel coronavirus (2019-nCoV) from Wuhan, Ch...   8.692931
# 34  ). We were also 72 able to successfully isolat...   8.533306
# 35  In late December 2019, an unusual pneumonia em...   8.464124
# 36  In late December 2019, an unusual pneumonia em...   8.464124
# 37  In the end of 2019, a novel coronavirus (2019-...   8.375391
# 38  In the end of 2019, a novel coronavirus (2019-...   8.324044
# 39  It is believed that the severe acute respirato...   8.240075
# 40  The virus species and accession number of the ...   8.151314
# 41  The catastrophic health and economic impacts o...   8.142541
# 42  The patient studied was a 41-year-old man with...   8.099710
# 43  Coronavirus disease 2019 (COVID‐19), which was...   8.028711
# 44  Nidoviruses are an ancient group of lipid-enve...   7.934869
# 45  Our ability to produce sequence data in the ra...   7.888766
# 46  Artificially intelligent robots, machines, and...   7.776895
# 47  human population remains mysterious, although ...   7.667037
# 48  Emerging infectious diseases represent a major...   7.666060
# 49  Yi Shi 1, * The ongoing COVID-19 pandemic has ...   7.638880

# %% [markdown]
# ### Q5: *Socioeconomic and behavioral risk factors for this spill-over*

# %%
p = '''
Socioeconomic and behavioral risk factors for this spill-over
'''
res = searchAndGetAnswer(p)
res
# Out:
# No valid answers found.
#                                                 title  \
# 0   Household financial vulnerability in Indonesia...
# 1   BigO: A public health decision support system ...
# 2             A deadly spillover: SARS-CoV-2 outbreak
# 3   Is Brazil prepared for the new era of infectio...
# 4   On the dynamics emerging from pandemics and in...
# 5   Exposure to air pollution and COVID-19 mortali...
# 6   COVID-19: the First Documented Coronavirus Pan...
# 7   Invasion Science and the Global Spread of SARS...
# 8              Horses as a Crucial Part of One Health
# 9   Climate affects global patterns of COVID-19 ea...
# 10  Synergistic China–US Ecological Research is Es...
# 11  Behavioral and Emotional Disorders in Children...
# 12  Racial/ethnic and socioeconomic disparities of...
# 13  Behavioral Food Addiction During Lockdown: Tim...
# 14  Impacts of social and economic factors on the ...
# 15  Spillover of SARS-CoV-2 into novel wild hosts ...
# 16  County-level factors influence the trajectory ...
# 17  Spillovers and diversification potential of ba...
# 18  Impacts of social and economic factors on the ...
# 19  Estimated inequities in COVID-19 infection fat...
# 20  Behavioral considerations and impact on person...
# 21  Understanding the Socio-Economic Disruption in...
# 22  Race, Socioeconomic Deprivation, and Hospitali...
# 23  The socio-economic determinants of the coronav...
# 24  A multi-group SEIRA model for the spread of CO...
# 25  Meta-regression of COVID-19 prevalence/fatalit...
# 26  Social and behavioral health responses to COVI...
# 27  Investigating spatial variability in COVID-19 ...
# 28                           New Virus, New Challenge
# 29  Globalized low-income countries may experience...
# 30  Why people failed to adhere to COVID-19 preven...
# 31        Impact of COVID-19 on Indian Sugar Industry
# 32  COVID-19 in patients with diabetes: risk facto...
# 33  Racial, Economic and Health Inequality and COV...
# 34  Stroke in patients with SARS-CoV-2 infection: ...
# 35  Determining risk factors for mortality in live...
# 36  Critical patients with coronavirus disease 201...
# 37  Causal Inference on Networks under Continuous ...
# 38  Outcomes from COVID-19 across the range of fra...
# 39  Risk factors for severe COVID-19 illness in he...
# 40  Coronavirus Disease (COVID-19) in Italy: Analy...
# 41  Prevalence, risk factors, and clinical correla...
# 42  Reply to “COVID-19 in persons with haematologi...
# 43  Early forecasting of the potential risk zones ...
# 44  Epidemiological and clinical characteristics o...
# 45  Symptom profiles and risk factors for hospital...
# 46  Initial Cluster of Novel Coronavirus (2019-nCo...
# 47  Applying the SEIR Model in Forecasting The COV...
# 48  Modifiable and non-modifiable risk factors for...
# 49  Letter to the Editor on ‘Risk Factors for Unpl...
#
#                                              abstract  \
# 0   This study assesses the level of financial vul...
# 1   Obesity is a complex disease and its prevalenc...
# 2                                                 NaN
# 3   Brazil must maintain a focus on enhancing the ...
# 4   This position paper discusses emerging behavio...
# 5   Objectives: United States government scientist...
# 6   The novel human coronavirus disease COVID-19 h...
# 7   Abstract Emerging infectious diseases like COV...
# 8   One Health (OH) is a crucial concept, where th...
# 9   Environmental factors, including seasonal clim...
# 10  The risk of a zoonotic pandemic disease threat...
# 11                                                NaN
# 12  We investigated the dependence of Covid-19 att...
# 13                                                NaN
# 14  This study models local and cross-city transmi...
# 15  Abstract There is evidence that the current ou...
# 16  With new cases of Covid-19 surging in the Unit...
# 17  Abstract We examine the network spillovers, po...
# 18  This paper examines the role of various socioe...
# 19  There is limited evidence as to how COVID-19 i...
# 20                                                NaN
# 21  In this paper, we collect and study Twitter co...
# 22  Preliminary reports suggest that the Coronavir...
# 23  The magnitude of the coronavirus disease (COVI...
# 24  The outbreak and propagation of COVID-19 have ...
# 25  To screen potential risk and protective socioe...
# 26  Our public health approaches to addressing COV...
# 27  Background: Spain has been disproportionately ...
# 28  The ongoing COVID-19 pandemic has made us to c...
# 29  Understanding the factors underpinning COVID-1...
# 30  These violations might endanger the community ...
# 31  The Indian sugar industry, a significant playe...
# 32                                                NaN
# 33  Abstract Background: There is preliminary evid...
# 34  BACKGROUND: Italy is one of the most affected ...
# 35                                                NaN
# 36                                                NaN
# 37  This paper presents a methodology to draw caus...
# 38  Purpose Our aim was to quantify the mortality ...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43  Recently, the coronavirus disease 2019 (COVID-...
# 44  Background: The first case of COVID-19 was det...
# 45                                                NaN
# 46  Reanalysis of the epidemic curve from the init...
# 47  On March 18, 2020 the Malaysian government imp...
# 48  Background Information on risk factors for COV...
# 49                                                NaN
#
#                                                   url  \
# 0   https://api.elsevier.com/content/article/pii/S...
# 1              https://arxiv.org/pdf/2005.02928v1.pdf
# 2   https://www.ncbi.nlm.nih.gov/pubmed/32321324/;...
# 3   https://www.ncbi.nlm.nih.gov/pubmed/32374800/;...
# 4              https://arxiv.org/pdf/2004.08917v1.pdf
# 5         https://doi.org/10.1101/2020.04.05.20054502
# 6   https://www.ncbi.nlm.nih.gov/pubmed/32387617/;...
# 7   https://www.sciencedirect.com/science/article/...
# 8   https://www.ncbi.nlm.nih.gov/pubmed/32121327/;...
# 9         https://doi.org/10.1101/2020.03.23.20040501
# 10  https://doi.org/10.1007/s10393-020-01471-2; ht...
# 11  https://www.ncbi.nlm.nih.gov/pubmed/32248989/;...
# 12             https://arxiv.org/pdf/2004.12175v1.pdf
# 13  https://doi.org/10.1007/s11695-020-04649-3; ht...
# 14  https://www.ncbi.nlm.nih.gov/pubmed/32395017/;...
# 15  https://api.elsevier.com/content/article/pii/S...
# 16  http://medrxiv.org/cgi/content/short/2020.05.0...
# 17  https://api.elsevier.com/content/article/pii/S...
# 18        https://doi.org/10.1101/2020.03.13.20035238
# 19  http://medrxiv.org/cgi/content/short/2020.04.2...
# 20  https://doi.org/10.1016/j.jaad.2020.03.013; ht...
# 21             https://arxiv.org/pdf/2004.05451v1.pdf
# 22  http://medrxiv.org/cgi/content/short/2020.04.2...
# 23  http://medrxiv.org/cgi/content/short/2020.04.1...
# 24  https://www.sciencedirect.com/science/article/...
# 25  http://medrxiv.org/cgi/content/short/2020.05.2...
# 26  https://doi.org/10.1007/s10865-020-00157-y; ht...
# 27        https://doi.org/10.1101/2020.04.14.20065524
# 28  https://www.sciencedirect.com/science/article/...
# 29        https://doi.org/10.1101/2020.03.31.20049122
# 30  https://doi.org/10.1017/ice.2020.245; https://...
# 31         https://doi.org/10.1007/s12355-020-00846-7
# 32  https://doi.org/10.1016/j.metabol.2020.154224;...
# 33  http://medrxiv.org/cgi/content/short/2020.04.2...
# 34  https://www.ncbi.nlm.nih.gov/pubmed/32436105/;...
# 35  https://api.elsevier.com/content/article/pii/S...
# 36  https://api.elsevier.com/content/article/pii/S...
# 37             https://arxiv.org/pdf/2004.13459v1.pdf
# 38  http://medrxiv.org/cgi/content/short/2020.05.2...
# 39  https://doi.org/10.1017/ice.2020.178; https://...
# 40  https://doi.org/10.3389/fmed.2020.00140; https...
# 41  https://www.ncbi.nlm.nih.gov/pubmed/32380272/;...
# 42  https://doi.org/10.1038/s41375-020-0877-y; htt...
# 43  https://api.elsevier.com/content/article/pii/S...
# 44  http://medrxiv.org/cgi/content/short/2020.04.2...
# 45  https://www.ncbi.nlm.nih.gov/pubmed/32437750/;...
# 46  https://doi.org/10.3390/jcm9020488; https://ww...
# 47  http://medrxiv.org/cgi/content/short/2020.04.1...
# 48  http://medrxiv.org/cgi/content/short/2020.04.2...
# 49  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
#
#                                               authors  \
# 0   Noerhidajati, Sri; Purwoko, Agung Bayu; Werdan...
# 1   Diou, Christos; Sarafis, Ioannis; Papapanagiot...
# 2   Mori, Mattia; Capasso, Clemente; Carta, Fabriz...
# 3                              Vicente, Creuza Rachel
# 4                                    Leitner, Stephan
# 5   Wu, Xiao; Nethery, Rachel C.; Sabath, Benjamin...
# 6          Liu, Yen-Chin; Kuo, Rei-Lin; Shih, Shin-Ru
# 7           Nuñez, M. A.; Pauchard, A.; Ricciardi, A.
# 8   Lönker, Nelly Sophie; Fechner, Kim; Abd El Wah...
# 9        Ficetola, Gentile Francesco; Rubolini, Diego
# 10  Smiley Evans, Tierra; Shi, Zhengli; Boots, Mic...
# 11  Jiao, Wen Yan; Wang, Lin Na; Liu, Juan; Fang, ...
# 12  Dobin, Daniel; School, Alexander Dobin Candlew...
# 13  Cherikh, Faredj; Frey, Sébastien; Bel, Corali;...
# 14                       Qiu, Yun; Chen, Xi; Shi, Wei
# 15                Franklin, Alan B.; Bevins, Sarah N.
# 16                        Kranjac, A. W.; Kranjac, D.
# 17  Arreola Hernandez, Jose; Hoon Kang, Sang; Huss...
# 18                       Qiu, Yun; Chen, Xi; Shi, Wei
# 19  Steyn, Nicholas; Binny, Rachelle N; Hannah, Ka...
# 20                                   Kantor, Jonathan
# 21  Shanthakumar, Swaroop Gowdra; Seetharam, Anand...
# 22  Patel, A. P.; Paranjpe, M. D.; Kathiresan, N. ...
# 23  Stojkoski, V.; Utkovski, Z.; Jolakoski, P.; Te...
# 24  Contreras, Sebastián; Villavicencio, H. Andrés...
# 25  Takagi, H.; Kuno, T.; Yokoyama, Y.; Ueyama, H....
# 26                 Eaton, Lisa A.; Kalichman, Seth C.
# 27  Dahal, Sushma; Mizumoto, Kenji; Rothenberg, Ri...
# 28                                            Shi, Yi
# 29  Jaffe, Rodolfo; Ortiz Vera, Mabel Patricia; Ja...
# 30  Chan, Derwin K. C.; Zhang, Chun-Qing; Weman-Jo...
# 31        Solomon, S.; Rao, Govind Pratap; Swapna, M.
# 32         Klonoff, David C.; Umpierrez, Guillermo E.
# 33  Abedi, V.; Olulana, O.; Avula, V.; Chaudhary, ...
# 34  Morassi, Mauro; Bagatto, Daniele; Cobelli, Mil...
# 35  Webb, Gwilym J; Moon, Andrew M; Barnes, Eleano...
# 36  Li, Lingzhi; Zhang, Binghong; He, Bing; Gong, ...
# 37  Prete, Davide Del; Forastiere, Laura; Sciabola...
# 38  Miles, A.; Webb, T. E.; Mcloughlin, B.; Mannan...
# 39  Wander, Pandora L.; Orlov, Marika; Merel, Susa...
# 40          Di Lorenzo, Giuseppe; Di Trolio, Rossella
# 41  Li, Xingxing; Yu, Haihang; Bian, Guolin; Hu, Z...
# 42  Fattizzo, Bruno; Giannotta, Juri Alessandro; S...
# 43  Ren, Hongyan; Zhao, Lu; Zhang, An; Song, Liuyi...
# 44  Souza, William Marciel de; Buss, Lewis Fletche...
# 45  Díaz, Luis Antonio; García-Salum, Tamara; Fuen...
# 46  Nishiura, Hiroshi; Linton, Natalie M.; Akhmetz...
# 47                             Mahmud, A.; Lim, P. Y.
# 48  Ho, F. K.; Celis-Morales, C. A.; Gray, S. R.; ...
# 49                Kamath, Atul F.; Piuzzi, Nicolas S.
#
#                                                  text      Score
# 0   The crisis in 2008, which was caused by securi...  12.580977
# 1   Obesity prevalence has been continuously risin...  11.940364
# 2   Coronaviruses (CoV) are a family of viruses th...  10.810611
# 3   Dear Editor:\nThe world has been facing a new ...  10.182449
# 4   in the direct aftermath of a pandemic are key ...  10.110361
# 5   The scale of the COVID-19 public health emerge...   9.560090
# 6   Currently, people all over the world have been...   9.036929
# 7   A sinister combination of ecosystem alteration...   8.917510
# 8   One Health (OH) is a holistic approach which d...   8.913372
# 9   1 Abstract 1 2 Environmental factors, includin...   8.739939
# 10  The catastrophic health and economic impacts o...   8.630575
# 11  The COVID-19 outbreak first erupted in the cit...   8.540292
# 12  The Covid-19 disease first emerged in late 201...   8.373394
# 13  The world is currently facing the COVID-19 pan...   8.356851
# 14  The first pneumonia case of unknown cause was ...   8.263538
# 15  J o u r n a l P r e -p r o o f 2 infected huma...   8.193293
# 16  The presence of severe acute respiratory syndr...   8.164640
# 17  The banking sector plays an important role in ...   8.139073
# 18  Several clusters of patients with pneumonia of...   8.116073
# 19  The COVID-19 outbreak originated in Wuhan Chin...   8.020653
# 20  In this issue of the JAAD, Lan et al1 provide ...   8.012635
# 21  COVID-19 (also known as the novel coronavirus)...   8.004584
# 22  The Coronavirus Disease 2019 (COVID-19) pandem...   7.973779
# 23  The coronavirus pandemic began as a simple out...   7.949000
# 24  Since the outbreak of novel SARS-CoV2 in late ...   7.915906
# 25  Reuters reported "The coronavirus mortality ra...   7.791638
# 26  Sustained, individual-level, behavioral change...   7.759786
# 27  The case fatality ratio is a useful metric to ...   7.747395
# 28  Yi Shi 1, * The ongoing COVID-19 pandemic has ...   7.638880
# 29  Understanding the factors underpinning COVID-1...   7.513772
# 30  The integrated model of self-determination the...   7.415810
# 31  Sugarcane is a long duration labour-intensive ...   7.404040
# 32  We agree with the conclusion by Dr. Hill and c...   7.260640
# 33  The complexity of managing patients with the C...   7.253174
# 34  Italy was the first country in Europe to witne...   7.194565
# 35  We read with great interest the Correspondence...   7.182662
# 36  Dear Editor,\nWe read Yang's paper with great ...   7.182662
# 37  Policies often involve interventions that spil...   7.130043
# 38  While it is clear that mortality from SARS-CoV...   7.123729
# 39  \nTo the Editor—We were very interested to rea...   7.106342
# 40  The lethality rate is determined as follows: t...   7.031626
# 41  Since December 2019, a large-scale outbreak of...   6.958465
# 42  We read with interest the article by He et al....   6.958465
# 43  Involving six continents, the outbreaks of the...   6.921999
# 44  The first case of COVID-19 was detected in Bra...   6.887059
# 45  San Carlos for their support to this project r...   6.886811
# 46  The clinical summary of the earliest cases of ...   6.875602
# 47  Universiti Putra Malaysia. CC-BY-NC-ND 4.0 Int...   6.856776
# 48  COVID-19, caused by SARS-CoV-2 infection, incl...   6.852470
# 49  We read with great interest the article by Suk...   6.816618

# %% [markdown]
# ### Q6: *Sustainable risk reduction strategies*

# %%
p = '''
Sustainable risk reduction strategies
'''
res = searchAndGetAnswer(p)
res
# Out:
# 1/10
# 2/10
# 3/10
# 4/10
# 5/10
# 6/10
# 7/10
# 8/10
# 9/10
# 10/10
#                                                title  \
# 0    Indirect effects of COVID-19 on the environment
# 1  Post COVID 19 and food pathways to sustainable...
# 2  A new vehicle to accelerate the UN Sustainable...
# 3  A Brave New World: Lessons from the COVID-19 P...
# 4  Editorial: Impacts of COVID-19 on agricultural...
# 5  From crisis to utopia: crafting new public–pri...
# 6  COVID-19 lockdowns cause global air pollution ...
# 7  Further analysis of the impact of distancing u...
# 8  A cloth mask for under-resourced healthcare se...
# 9  Preparing your intensive care unit for the COV...
#
#                                             abstract Answer     Score  \
# 0  Abstract This research aims to show the positi...  【  】   9.350980
# 1                                                NaN  【  】   9.074676
# 2                                                NaN  【  】   8.976158
# 3                                                NaN  【  】   8.693033
# 4                                                NaN  【  】   8.602586
# 5                                                NaN  【  】   8.514002
# 6  The lockdown response to COVID-19 has caused a...  【  】   8.450780
# 7  This paper questions various claims from the p...  【  】   8.254299
# 8  INTRODUCTION: COVID19 pandemic poses a global ...  【  】   8.101378
# 9  The coronavirus disease 2019 (COVID-19) has ra...  【  】   8.032679
#
#                                                  url  \
# 0  https://api.elsevier.com/content/article/pii/S...
# 1  https://doi.org/10.1007/s10460-020-10051-7; ht...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 3  https://www.ncbi.nlm.nih.gov/pubmed/32313383/;...
# 4  https://www.sciencedirect.com/science/article/...
# 5  https://www.ncbi.nlm.nih.gov/pubmed/32395003/;...
# 6        https://doi.org/10.1101/2020.04.10.20060673
# 7        https://doi.org/10.1101/2020.04.14.20048025
# 8  https://www.ncbi.nlm.nih.gov/pubmed/32394153/;...
# 9  https://doi.org/10.1186/s13054-020-02916-4; ht...
#
#                                              authors
# 0  Zambrano-Monserrate, Manuel A.; Ruano, María A...
# 1  Blay-Palmer, Alison; Carey, Rachel; Valette, E...
# 2  Sherr, Lorraine; Cluver, Lucie; Desmond, Chris...
# 3  Sarkis, Joseph; Cohen, Maurie J.; Dewick, Paul...
# 4  Stephens, Emma; Martin, Guillaume; van Wijk, M...
# 5                                     Caron, Patrick
# 6  Venter, Zander S; Aunan, Kristin; Chowdhury, S...
# 7                               Bernstein, Daniel J.
# 8  Sugrue, Michael; O’Keeffe, Derek; Sugrue, Ryan...
# 9  Goh, Ken Junyang; Wong, Jolin; Tien, Jong-Chie...
